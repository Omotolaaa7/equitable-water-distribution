# %% [markdown]
# # Exploration libre — Thème 3, Groupe 1
#
# **Ce notebook n'est pas un livrable.**
#
# La section 10.3 du plan de projet est explicite : le notebook sert à essayer
# rapidement des idées et à visualiser des résultats intermédiaires, mais il *ne
# remplace jamais le code propre et documenté du dossier* `src/`.
#
# Règle de travail : dès qu'un bout de code fonctionne ici, il migre dans `src/`
# avec son docstring et son test. Rien de ce qui compte pour la note ne doit
# exister uniquement dans un notebook — un correcteur ne relit pas les brouillons,
# et un notebook n'est pas relisible en pull request.

# %%
import sys
from pathlib import Path

RACINE = Path.cwd().parent
if str(RACINE) not in sys.path:
    sys.path.insert(0, str(RACINE))

import numpy as np
import matplotlib.pyplot as plt

CONFIG = RACINE / "data" / "network_config.json"

# %% [markdown]
# ## 1. Le réseau
#
# Charger `network_config.json`, tracer le graphe, repérer visuellement les points
# de fragilité. Un dessin du réseau vaut mieux qu'une lecture du JSON pour valider
# collectivement la topologie de M1.

# %%
# from src.graph.build_graph import construire_graphe
# reseau = charger_reseau(CONFIG)

# %% [markdown]
# ## 2. La matrice d'incidence
#
# Vérifier à l'œil que chaque colonne de A porte un `+1` et un `-1`, puis
# confronter le rang mesuré au résultat démontré `rang(A) = n - k`.

# %% [markdown]
# ## 3. Le modèle de demande
#
# Tirer quelques scénarios, tracer les histogrammes, vérifier que les corrélations
# empiriques retrouvent bien celles déclarées dans la configuration.
#
# Chiffrer aussi `P(D_i < 0)` : c'est la limite de la loi gaussienne pour une
# grandeur positive, et le rapport doit l'assumer avec un nombre plutôt qu'une
# formule d'excuse.

# %% [markdown]
# ## 4. Bac à sable
#
# ⚠ Rien de ce qui touche à `src/optimization/` ne doit être essayé ici avant que
# les huit points du jalon (section 16 du plan) soient cochés. Le notebook n'est
# pas une porte dérobée pour coder le gradient avant de l'avoir dérivé.
